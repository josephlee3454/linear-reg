# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# test for imports

# %% [markdown]
# Load and recieve data

# %%
nfl_rush_df = pd.read_csv('./Career_Stats_Rushing.csv')
nfl_rush_df
# Out:
#                   Player Id            Name Position  Year  \
# 0         fredevans/2513736     Evans, Fred      NaN  1948
# 1         fredevans/2513736     Evans, Fred      NaN  1948
# 2         fredevans/2513736     Evans, Fred      NaN  1947
# 3         fredevans/2513736     Evans, Fred      NaN  1947
# 4         fredevans/2513736     Evans, Fred      NaN  1946
# ...                     ...             ...      ...   ...
# 17502  billanderson/2508534  Anderson, Bill      NaN  1962
# 17503  billanderson/2508534  Anderson, Bill      NaN  1961
# 17504  billanderson/2508534  Anderson, Bill      NaN  1960
# 17505  billanderson/2508534  Anderson, Bill      NaN  1959
# 17506  billanderson/2508534  Anderson, Bill      NaN  1958
#
#                       Team  Games Played Rushing Attempts  \
# 0            Chicago Bears             3               10
# 1          Chicago Rockets             0               --
# 2          Chicago Rockets             0               --
# ...

# %% [markdown]
# I know i needed the first five but when i did the first five it gave the same really low person so i decided to sort it after anderson gary so it would give me the leaders

# %%
nfl_rush_leader = nfl_rush_df['Name'].value_counts().idxmax()
nfl_rush_leader
# Out:
# 'Anderson, Gary'

# %%
sorted_rush_col = nfl_rush_df.sort_values("Rushing Yards", ascending=False)
sorted_rush_col
# Out:
#                    Player Id             Name Position  Year  \
# 5631     davehampton/2515722    Hampton, Dave      NaN  1973
# 14747          mattforte/234      Forte, Matt       RB  2011
# 6008    essexjohnson/2517628   Johnson, Essex      NaN  1973
# 10016   melvingordon/2552469   Gordon, Melvin       RB  2016
# 5632     davehampton/2515722    Hampton, Dave      NaN  1972
# ...                      ...              ...      ...   ...
# 8580   henrymatthews/2520364  Matthews, Henry      NaN  1972
# 8578   henrymatthews/2520364  Matthews, Henry      NaN  1973
# 8576     harperdavis/2512584    Davis, Harper      NaN  1949
# 8574     harperdavis/2512584    Davis, Harper      NaN  1951
# 17506   billanderson/2508534   Anderson, Bill      NaN  1958
#
#                        Team  Games Played Rushing Attempts  \
# 5631        Atlanta Falcons            14              263
# 14747         Chicago Bears            12              203
# ...

# %%
sorted_rush_col.head(5)
# Out:
#                   Player Id            Name Position  Year  \
# 5631    davehampton/2515722   Hampton, Dave      NaN  1973
# 14747         mattforte/234     Forte, Matt       RB  2011
# 6008   essexjohnson/2517628  Johnson, Essex      NaN  1973
# 10016  melvingordon/2552469  Gordon, Melvin       RB  2016
# 5632    davehampton/2515722   Hampton, Dave      NaN  1972
#
#                      Team  Games Played Rushing Attempts  \
# 5631      Atlanta Falcons            14              263
# 14747       Chicago Bears            12              203
# 6008   Cincinnati Bengals            14              195
# 10016  San Diego Chargers            13              254
# 5632      Atlanta Falcons            13              230
#
#        Rushing Attempts Per Game Rushing Yards Yards Per Carry  \
# 5631                        18.8           997             3.8
# 14747                       16.9           997             4.9
# 6008                        13.9           997             5.1
# ...

# %% [markdown]
# no its only showing the rb postion and its suppose to be sorted by rushing yards but there is somthing wrong with data comming in

# %%
only_rb = nfl_rush_df[nfl_rush_df['Position']=='RB']
rb_rush_yards = only_rb.sort_values("Rushing Yards")
only_rb_over_val = only_rb[only_rb['Rushing Yards']>='600']
sort_only_rb_over_var = only_rb_over_val.sort_values("Rushing Yards")
sort_only_rb_over_var.tail(100)
# Out:
#                     Player Id               Name Position  Year  \
# 14680       dionlewis/2495469        Lewis, Dion       RB  2012
# 15596  giovanibernard/2540156   Bernard, Giovani       RB  2013
# 5463      bilalpowell/2495328      Powell, Bilal       RB  2013
# 6086       alfredblue/2543600       Blue, Alfred       RB  2015
# 12909    kenjonbarner/2539289     Barner, Kenjon       RB  2013
# ...                       ...                ...      ...   ...
# 1438       carloshyde/2543743       Hyde, Carlos       RB  2016
# 3107      jonathanstewart/949  Stewart, Jonathan       RB  2015
# 2082      lancedunbar/2535708      Dunbar, Lance       RB  2014
# 10016    melvingordon/2552469     Gordon, Melvin       RB  2016
# 14747           mattforte/234        Forte, Matt       RB  2011
#
#                       Team  Games Played Rushing Attempts  \
# 14680  Philadelphia Eagles             9               13
# 15596   Cincinnati Bengals            16              170
# ...

# %%
X = sort_only_rb_over_var["Rushing Attempts"].values
y = sort_only_rb_over_var["Team"].values
x
y
# Out:
# array(['Green Bay Packers', 'New Orleans Saints', 'New Orleans Saints',
#        'Cleveland Browns', 'San Francisco 49ers', 'Denver Broncos',
#        'Oakland Raiders', 'Seattle Seahawks', 'New York Jets',
#        'New York Giants', 'Kansas City Chiefs', 'Philadelphia Eagles',
#        'New York Giants', 'New York Jets', 'Green Bay Packers',
#        'Baltimore Ravens', 'San Diego Chargers', 'Detroit Lions',
#        'Jacksonville Jaguars', 'Philadelphia Eagles', 'New York Jets',
#        'Dallas Cowboys', 'Dallas Cowboys', 'Cleveland Browns',
#        'San Diego Chargers', 'Cincinnati Bengals', 'Philadelphia Eagles',
#        'Cincinnati Bengals', 'New York Jets', 'Houston Texans',
#        'Carolina Panthers', 'Pittsburgh Steelers', 'Jacksonville Jaguars',
#        'Pittsburgh Steelers', 'Pittsburgh Steelers',
#        'Philadelphia Eagles', 'New England Patriots',
#        'Washington Redskins', 'Cleveland Browns', 'San Diego Chargers',
# ...

# %%
X = X.reshape(-1,1)

# %%
x
# Out:
#                     Player Id               Name Position  Year  \
# 11933   christhompson/2540011    Thompson, Chris       RB  2013
# 9540   jonathangrimes/2534770   Grimes, Jonathan       RB  2012
# 4806       dannywoodhead/4327    Woodhead, Danny       RB  2010
# 8515    travariscadet/2535890    Cadet, Travaris       RB  2015
# 8517    travariscadet/2535890    Cadet, Travaris       RB  2013
# ...                       ...                ...      ...   ...
# 1438       carloshyde/2543743       Hyde, Carlos       RB  2016
# 3107      jonathanstewart/949  Stewart, Jonathan       RB  2015
# 2082      lancedunbar/2535708      Dunbar, Lance       RB  2014
# 14747           mattforte/234        Forte, Matt       RB  2011
# 10016    melvingordon/2552469     Gordon, Melvin       RB  2016
#
#                        Team  Games Played Rushing Attempts  \
# 11933   Washington Redskins             4               --
# 9540   Jacksonville Jaguars             0               --
# ...
